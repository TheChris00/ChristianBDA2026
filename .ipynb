# %% [markdown]
# # Task
#
# task you were performing is called Mean Centering.
# You were calculating the deviation of each individual observation from the sample mean.

# %%
import pandas as pd
data = pd.read_csv("/Users/chris/Desktop/ChristianBDA2026/data/symbol_info_3-25.csv")


data_sample = data.sample(40, random_state=42)

data_sample = data_sample[["enterprise_value"]]

print(data_sample)
# Out:
#          enterprise_value
# 521           16978455552
# 737           18454824960
# 740           16518365184
# 660           12900748288
# 411           25722433536
# 678           29060794368
# 626           15252375552
# 513           22880147456
# 859           11469899776
# 136           97136320512
# 811           14598353920
# 76           172757499904
# 636           13978393600
# 973            7509071360
# 938            4931700736
# 899           12892424192
# 280           48276049920
# 883            8955035648
# 761           12001590272
# 319           47703121920
# 549           11656066048
# 174           70468927488
# 371           28853374976
# 527           32853676032
# 210           92796944384
# 235           57322881024
# 101         1787881062400
# 986           11104132096
# 902            7302352384
# 947            7868419584
# 346           39011151872
# 139           87613440000
# 621           21969678336
# 499           19469418496
# ...

# %%
data_sample['diff_ev'] = data_sample['enterprise_value'] - avg_e

print(avg_e)
data_sample.head()

print(f"Media Enterprise Value: {avg_e:.2f}")
print(data_sample.head())
# Out:
# 4.6116867892482746e+17
# Media Enterprise Value: 461168678924827456.00
#      enterprise_value       diff_ev
# 521       16978455552 -4.611687e+17
# 737       18454824960 -4.611687e+17
# 740       16518365184 -4.611687e+17
# 660       12900748288 -4.611687e+17
# 411       25722433536 -4.611687e+17
